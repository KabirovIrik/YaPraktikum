# %% [markdown]
# # Шаг 1 Изучение информации
# Интернет-магазин «Стримчик» по всему миру продаёт компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %%
import string
from scipy import stats as st
import numpy as np
from matplotlib import pyplot as plt
import math
import pandas as pd
import seaborn as sns 

data = pd.read_csv('/datasets/games.csv')
data.columns = [col.lower() for col in data.columns] # Названия столбцов приведем к нижнему регистру

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data['platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %%
data['genre'].value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: genre, dtype: int64

# %%
data['rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# ## Шаг 1 Вывод
# **name** - есть пропуск, также стоит преобразовать к одному регистру и поискать дубли<br>
# **platform** - нет проблем <br>
# **year_of_release** - имеются пропуски, тип данных можно перевести в Даты <br>
# **genre** - есть пара пропусков <br>
# **na_sales**,	**eu_sales**,	**jp_sales**,	**other_sales** - нет проблем <br>
# **critic_score** - есть пропуски<br>
# **user_score** - есть пропуски и нужно преобразовать в вещественный тип данных<br>
# **rating** - етсь пропуски

# %% [markdown]
# <hr>
#
# # Шаг 2 Подготовка данных

# %% [markdown]
# ## Шаг 2.1  Удаление пропусков и преобразование данных

# %% [markdown]
# Удалим пропуски в столбце **year_of_release** и преобрузаем в целочисленный тип

# %%
data[data['year_of_release'].isnull()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# 377          Sports      0.59      2.36      0.04         0.51          84.0
# 456          Action      1.80      0.97      0.00         0.29          74.0
# 475        Fighting      1.57      1.02      0.00         0.41           NaN
# 609         Shooter      2.36      0.14      0.00         0.03           NaN
# ...             ...       ...       ...       ...          ...           ...
# 16373        Sports      0.01      0.00      0.00         0.00          43.0
# 16405        Racing      0.01      0.00      0.00         0.00          69.0
# 16448       Shooter      0.01      0.00      0.00         0.00          59.0
# 16458     Adventure      0.01      0.00      0.00         0.00           NaN
# 16522  Role-Playing      0.01      0.00      0.00         0.00          55.0
#
#       user_score rating
# 183          8.5      E
# 377          6.4      E
# 456          7.9   E10+
# 475          NaN    NaN
# 609          NaN    NaN
# ...          ...    ...
# 16373        tbd   E10+
# 16405        6.5      T
# 16448        6.7      M
# 16458        NaN    NaN
# 16522        5.5      T
#
# [269 rows x 11 columns]

# %%
print("Пропусков в столбце year_of_release:", len(data[data['year_of_release'].isnull()]))
print("Доля попусков в столбце year_of_release:", round(len(data[data['year_of_release'].isnull()])/len(data) * 100, 2), "%")
# Out:
# Пропусков в столбце year_of_release: 269
# Доля попусков в столбце year_of_release: 1.61 %

# %% [markdown]
# Пропуски годов нельзя заполнить средним, медианным или каким-либо другим значением. Их немного поэтому лучше удалить.

# %%
data = data[data['year_of_release'].notnull()]
data['year_of_release'] = pd.to_datetime(data['year_of_release'], format="%Y").dt.year
len(data[data['year_of_release'].isnull()])
# Out:
# 0

# %% [markdown]
# <hr>
#
# Пропуски в **genre**

# %%
data[data['genre'].isnull()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Почти все поля в этих строках пропущены. Лучше удалить эти строки

# %%
data = data[data['genre'].notnull()]
len(data[data['genre'].isnull()])
# Out:
# 0

# %% [markdown]
# <hr>
#
# Пропуски в **critic_score**, **user_score**

# %%
data[data['critic_score'].isnull()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# 5         23.20      2.26      4.22         0.58           NaN        NaN
# 9         26.93      0.63      0.28         0.47           NaN        NaN
# 10         9.05     10.95      1.93         2.74           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       rating
# 1        NaN
# 4        NaN
# 5        NaN
# 9        NaN
# 10       NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [8461 rows x 11 columns]

# %%
data[data['user_score'].isnull()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# 5         23.20      2.26      4.22         0.58           NaN        NaN
# 9         26.93      0.63      0.28         0.47           NaN        NaN
# 10         9.05     10.95      1.93         2.74           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       rating
# 1        NaN
# 4        NaN
# 5        NaN
# 9        NaN
# 10       NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [6605 rows x 11 columns]

# %%
data[data['user_score'] == 'tbd']
# Out:
#                                  name platform  year_of_release       genre  \
# 119                     Zumba Fitness      Wii             2010      Sports
# 301    Namco Museum: 50th Anniversary      PS2             2005        Misc
# 520                   Zumba Fitness 2      Wii             2011      Sports
# 645                      uDraw Studio      Wii             2010        Misc
# 718                   Just Dance Kids      Wii             2010        Misc
# ...                               ...      ...              ...         ...
# 16695                 Planet Monsters      GBA             2001      Action
# 16697                Bust-A-Move 3000       GC             2003      Puzzle
# 16698                Mega Brain Boost       DS             2008      Puzzle
# 16704                        Plushees       DS             2008  Simulation
# 16706   Men in Black II: Alien Escape       GC             2003     Shooter
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 119        3.45      2.59       0.0         0.66           NaN        tbd
# 301        2.08      1.35       0.0         0.54          61.0        tbd
# 520        1.51      1.03       0.0         0.27           NaN        tbd
# 645        1.65      0.57       0.0         0.20          71.0        tbd
# 718        1.52      0.54       0.0         0.18           NaN        tbd
# ...         ...       ...       ...          ...           ...        ...
# 16695      0.01      0.00       0.0         0.00          67.0        tbd
# 16697      0.01      0.00       0.0         0.00          53.0        tbd
# 16698      0.01      0.00       0.0         0.00          48.0        tbd
# 16704      0.01      0.00       0.0         0.00           NaN        tbd
# 16706      0.01      0.00       0.0         0.00           NaN        tbd
#
#       rating
# 119        E
# 301     E10+
# 520        T
# 645        E
# 718        E
# ...      ...
# 16695      E
# 16697      E
# 16698      E
# 16704      E
# 16706      T
#
# [2376 rows x 11 columns]

# %% [markdown]
# Пропусков досточно много. Удалять их не стоит. **user_score** надо преобразовать в тип float, но сначала разобраться со значением **tbd**. Эта аббревиатура переводится как "To Be Determined" - "будет определено". Наверное можно заменить на NaN.

# %%
data['user_score'] = data['user_score'].apply(lambda val: float('NaN') if val == 'tbd' else val).astype('float')
print(len(data[data['user_score'] == 'tbd']))
data.info()
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null int64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         7463 non-null float64
# rating             9768 non-null object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB
# /opt/conda/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %% [markdown]
# <hr>
#
# Рассмотрим **rating**:

# %%
data[data['rating'].isnull()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES             1985      Platform
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                             Tetris       GB             1989        Puzzle
# 9                          Duck Hunt      NES             1984       Shooter
# 10                        Nintendogs       DS             2005    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 1         29.08      3.58      6.81         0.77           NaN         NaN
# 4         11.27      8.89     10.22         1.00           NaN         NaN
# 5         23.20      2.26      4.22         0.58           NaN         NaN
# 9         26.93      0.63      0.28         0.47           NaN         NaN
# 10         9.05     10.95      1.93         2.74           NaN         NaN
# ...         ...       ...       ...          ...           ...         ...
# 16710      0.00      0.00      0.01         0.00           NaN         NaN
# 16711      0.00      0.01      0.00         0.00           NaN         NaN
# 16712      0.00      0.00      0.01         0.00           NaN         NaN
# 16713      0.01      0.00      0.00         0.00           NaN         NaN
# 16714      0.00      0.00      0.01         0.00           NaN         NaN
#
#       rating
# 1        NaN
# 4        NaN
# 5        NaN
# 9        NaN
# 10       NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [6676 rows x 11 columns]

# %% [markdown]
# В **rating** также слишком много пропусков и заменить каким-то значением по-умолчанию не получится.

# %% [markdown]
# <hr>
#
# ## Шаг 2.1 Вывод
# Были удалены записи с небольшим количеством пропусков (**year_of_release**, **name** и **genre**). <br>
# Пропуски в столбцах с оценкой игр оставили (**critic_score**, **user_score**, **rating**): их слишком много для удаления, а замену не стоит делать, т.к. это может сказаться на дальнейшем анализе <br>
# Преобразовали тип данных в столбцах: **year_of_release** в DateTime, **user_score** в float. <br>
#
# <hr>
#
# Пропуски в **name**, **genre** обусловлены какой-то программной ошибкой, т.к. в записях с этими полями почти все другие поля тоже отсутствуют. <br>
# Пропуски в **year_of_release**, **other_sales**, **critic_score**, **user_score**, **rating** вероятно появились при сборе информации, хотя информация есть в интернете (wikipedia, Metacritic).<br>
# В идеале данные можно попробовать собрать/спарсить еще раз, но сейчас оставим как есть<br>

# %% [markdown]
# <hr>
#
# ## Шаг 2.2 Суммарная продажа по регионам
#
# Добавим столб с общей суммой продаж по всем регионам

# %%
data['sum_sales'] = data.apply(lambda row: row['na_sales'] + row['eu_sales'] + row['jp_sales'] + row['other_sales'], axis=1)
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  sum_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1      3.58      6.81         0.77           NaN         NaN    NaN      40.24
# 2     12.76      3.79         3.29          82.0         8.3      E      35.52
# 3     10.93      3.28         2.95          80.0         8.0      E      32.77
# 4      8.89     10.22         1.00           NaN         NaN    NaN      31.38

# %% [markdown]
# <hr>
#
# ## Шаг 2.3 Проверка на дубли

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Шаг 2 Вывод
# Преобразовали в некоторых столбцах типы данных.<br>
# Некоторые пропуски удалили, но большую часть оставили и не заменяли, т.к. их много и в ддальнейшем замена могла бы повлиять на анализ данных.<br>
# Дубликатов найдено не было<br>
# Добавил столбец с общей суммой продаж

# %% [markdown]
# <hr>
#
# # Шаг 3 Исследовательский анализ данных

# %% [markdown]
# ## Шаг 3.1 Количество игр в год

# %%
game_per_year = data.groupby('year_of_release')['name'].count()
game_per_year
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %%
game_per_year.plot()

# %% [markdown]
# Сверху учитывался все записи из датасета, т.е. и те игры, которые выходили на разные платформы. Теперь взглянем только на уникальные игры

# %%
uniq_name = data.drop_duplicates(subset='name')
game_per_year = uniq_name.groupby('year_of_release')['name'].count()
game_per_year
# Out:
# year_of_release
# 1980      8
# 1981     43
# 1982     33
# 1983     16
# 1984     13
# 1985     13
# 1986     21
# 1987     15
# 1988     11
# 1989     14
# 1990     14
# 1991     40
# 1992     37
# 1993     58
# 1994    112
# 1995    200
# 1996    247
# 1997    268
# 1998    347
# 1999    293
# 2000    300
# 2001    410
# 2002    573
# 2003    491
# 2004    521
# 2005    617
# 2006    729
# 2007    838
# 2008    987
# 2009    957
# 2010    862
# 2011    750
# 2012    406
# 2013    293
# 2014    279
# 2015    331
# 2016    279
# Name: name, dtype: int64

# %%
game_per_year.plot()

# %% [markdown]
# ## Шаг 3.1 Вывод
# Начиная с 1994 начался росто выпуска игра, а с 2002  по 2009 был еще более резкий скачок, а потом спад. В качестве актуального периода стоит взять с 1994 по 2016 года. Пик был в 2008 году. <br>
# Также взглянули только на уникальные игры: собственно график по форме почти совпадает с графиком по всему датасету и выводы остаются те же.

# %% [markdown]
# <hr>
#
# ## Шаг 3.2 Продажа по платформам
# Посмотрим сумму продаж по платформам начиная с 1994 года

# %%
platform_data = data.pivot_table(
                        index='year_of_release', 
                        columns='platform',
                        values='sum_sales', 
                        aggfunc='sum',
                        fill_value=0,
                        margins=True
                )
platform_data = platform_data.drop(columns='All')
cm = sns.light_palette("green", as_cmap=True)
s = platform_data.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_92efa388_4124_11ea_a6a7_02420a007493row0_col0 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col14 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col15 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col16 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col17 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col18 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col19 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col20 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col21 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col22 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col23 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col24 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col25 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col26 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col27 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col28 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col29 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row0_col30 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col0 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col14 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col15 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col16 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col17 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col18 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col19 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col20 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col21 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col22 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col23 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col24 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col25 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col26 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col27 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_92efa388_4124_11ea_a6a7_02420a007493row1_col28 {
#             background-color:  #

# %% [markdown]
# Оставим платформы с суммарной продаже больше 159 млн. долларов

# %%
platform_data = platform_data.drop(columns=platform_data.loc['All', ~(platform_data > 159).any()].index)
cm = sns.light_palette("green", as_cmap=True)
s = platform_data[:-1].style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_933d6654_4124_11ea_a6a7_02420a007493row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col14 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col15 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col16 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row0_col17 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col14 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col15 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col16 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row1_col17 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col14 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col15 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col16 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row2_col17 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_933d6654_4124_11ea_a6a7_02420a007493row3_col5 {
#             background-color:  #e5ffe5;

# %%
platform_data[:-1].plot(kind='bar', figsize=(16, 8))

# %% [markdown]
# ## Шаг 3.2 Вывод
#
# Во всех платформах, кроме PC, продажи идут около 5-7 лет. Очевидно, связано с тем, что выходит новое поколоение этой платформы, например (PS,PS2, PS3, PS4)<br>
# На данный момент можно выделить 3 актуальные платформы: PC, XOne, PS4. Второстепенные, но еще продаваемые, это: PS3, 3DS, X360.<br>
# PC не вырывается в лидеры, но с 1994 не скатывается до нуля. <br>
# Также следует отметить сильный спад в 2016 год, предположительно это связано не с самими продажами, а с актуальностью собранной информации

# %% [markdown]
# <hr>
#
# ## Шаг 3.3 Выбор актуального периода

# %% [markdown]
# Актуальным периодом берем с 2010 по 2016, т.к. в 2010 был пик продаж для платформ PS3, 3DS, X360, которые еще актуальны на 2016 год, и с 2013 уже начали появляться платформы последнего поколения.

# %%
data_actual = data[data['year_of_release'] >= 2010]
data_actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5277 entries, 14 to 16714
# Data columns (total 12 columns):
# name               5277 non-null object
# platform           5277 non-null object
# year_of_release    5277 non-null int64
# genre              5277 non-null object
# na_sales           5277 non-null float64
# eu_sales           5277 non-null float64
# jp_sales           5277 non-null float64
# other_sales        5277 non-null float64
# critic_score       2312 non-null float64
# user_score         2499 non-null float64
# rating             3113 non-null object
# sum_sales          5277 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 535.9+ KB

# %% [markdown]
# <hr>
#
# ## Шаг 3.4 Лидирующие платформы

# %% [markdown]
# Согласно предыдущим анализам данных, прибыльными платформами являются XOne и PS4. Менее прибыльные, т.е. продажи которых уже падают: PS3, 3DS, X360. У PC продажи не такие большие, но они не падают.

# %%
platform_list = ['XOne', 'PS4', 'PS3', '3DS', 'X360', 'PC']
data_actual = data_actual[data_actual['platform'].isin(platform_list)]
data_actual
# Out:
#                                     name platform  year_of_release     genre  \
# 14                    Kinect Adventures!     X360             2010      Misc
# 16                    Grand Theft Auto V      PS3             2013    Action
# 23                    Grand Theft Auto V     X360             2013    Action
# 29        Call of Duty: Modern Warfare 3     X360             2011   Shooter
# 31             Call of Duty: Black Ops 3      PS4             2015   Shooter
# ...                                  ...      ...              ...       ...
# 16691       Dynasty Warriors: Eiketsuden      PS3             2016    Action
# 16692  Metal Gear Solid V: Ground Zeroes       PC             2014    Action
# 16696                             Breach       PC             2011   Shooter
# 16702            STORM: Frontline Nation       PC             2011  Strategy
# 16710      Samurai Warriors: Sanada Maru      PS3             2016    Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 14        15.00      4.89      0.24         1.69          61.0         6.3
# 16         7.02      9.09      0.98         3.96          97.0         8.2
# 23         9.66      5.14      0.06         1.41          97.0         8.1
# 29         9.04      4.24      0.13         1.32          88.0         3.4
# 31         6.03      5.86      0.36         2.38           NaN         NaN
# ...         ...       ...       ...          ...           ...         ...
# 16691      0.00      0.00      0.01         0.00           NaN         NaN
# 16692      0.00      0.01      0.00         0.00          80.0         7.6
# 16696      0.01      0.00      0.00         0.00          61.0         5.8
# 16702      0.00      0.01      0.00         0.00          60.0         7.2
# 16710      0.00      0.00      0.01         0.00           NaN         NaN
#
#       rating  sum_sales
# 14         E      21.82
# 16         M      21.05
# 23         M      16.27
# 29         M      14.73
# 31       NaN      14.63
# ...      ...        ...
# 16691    NaN       0.01
# 16692      M       0.01
# 16696      T       0.01
# 16702   E10+       0.01
# 16710    NaN       0.01
#
# [3199 rows x 12 columns]

# %% [markdown]
# <hr>
#
# ## Шаг 3.5 «ящик с усами» по глобальным продажам каждой игры

# %%
plt.figure(figsize=(20,10))
sns.boxplot(y="platform", x="sum_sales", data=data_actual, orient="h")

# %%
plt.figure(figsize=(20,10))
plt.xlim(0, 2)
sns.boxplot(y="platform", x="sum_sales", data=data_actual, orient="h",showmeans=True)

# %%
for pf in platform_list:
    print('Среднее для {}: \t{}'.format(pf, round(data_actual[data_actual['platform']==pf]['sum_sales'].mean(), 3)))
# Out:
# Среднее для XOne: 	0.645
# Среднее для PS4: 	0.801
# Среднее для PS3: 	0.661
# Среднее для 3DS: 	0.504
# Среднее для X360: 	0.809
# Среднее для PC: 	0.255

# %% [markdown]
# ## Шаг 3.5 Вывод
# По диаграмме видно, что продажи X360, XOne, PS3 и PS4 почти совпадают. 3DS имеет меньшее значение продаж, и самое маленькое значение у PC.<br>
# Среднее значение продаж разнится сильнее, но все равно X360, XOne, PS3 и PS4 почти равны, а 3DS и PC отстают. <br>
# PS4 можно назвать лидирующей платформой, т.к. она относится к последнему поколению консолей и имеет более высокий 75% процентиль по сравнению с XOne.

# %% [markdown]
# <hr>
#
# ## Шаг 3.6 Анализ влияния отзывов в популярной платформе

# %%
top_pf_data = data_actual[data_actual['platform'] == 'PS4']
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

top_pf_data.plot(kind='scatter', y='sum_sales', x='critic_score', ax=axes[0], alpha=0.3)
top_pf_data.plot(kind='scatter', y='sum_sales', x='user_score', ax=axes[1], alpha=0.3)

# %%
print('Коррелляция между продажами и оценками критиков: \t', round(top_pf_data['sum_sales'].corr(top_pf_data['critic_score']), 3))
print('Коррелляция между продажами и оценками пользователей: \t', round(top_pf_data['sum_sales'].corr(top_pf_data['user_score']), 3))
# Out:
# Коррелляция между продажами и оценками критиков: 	 0.407
# Коррелляция между продажами и оценками пользователей: 	 -0.032

# %% [markdown]
# ## Шаг 3.6 Вывод
# Между продажами и оценками критиков есть небольшая коррелляция, а между продажами и оценками пользователей нет четкой линейной коррелляции, хотя на графике слабая, с выбросами, зависимость все же есть.

# %% [markdown]
# <hr>
#
# ## Шаг 3.7 Анализ влияния отзывов на остальных платформах

# %%
fig, axes = plt.subplots(len(platform_list), 2, figsize=(15, 20))
plt.subplots_adjust(hspace=.8)
for i in range(len(platform_list)):
    pf = platform_list[i]
    data_actual[data_actual['platform'] == pf].plot(
        kind='scatter', 
        y='sum_sales', 
        x='critic_score',
        alpha=0.3,
        ax=axes[i, 0]
    )
    data_actual[data_actual['platform'] == pf].plot(
        kind='scatter', 
        y='sum_sales', 
        x='user_score',
        alpha=0.3,
        ax=axes[i, 1]
    )    
    axes[i, 0].set(title = pf+': оценки критиков', xlim=(0, 100))
    axes[i, 1].set(title = pf+': оценки пользователей', xlim=(0, 10))

# %%
print('Коррелляция между продажами и оценками')
for pf in platform_list:
    print(pf)
    print('Коррелляция c оценками критиков: \t', 
          round(data_actual[data_actual['platform'] == pf]['sum_sales'].corr(data_actual[data_actual['platform'] == pf]['critic_score']), 3))
    print('Коррелляция c оценками пользователей: \t', 
          round(data_actual[data_actual['platform'] == pf]['sum_sales'].corr(data_actual[data_actual['platform'] == pf]['user_score']), 3))
    print()
# Out:
# Коррелляция между продажами и оценками
# XOne
# Коррелляция c оценками критиков: 	 0.417
# Коррелляция c оценками пользователей: 	 -0.069
#
# PS4
# Коррелляция c оценками критиков: 	 0.407
# Коррелляция c оценками пользователей: 	 -0.032
#
# PS3
# Коррелляция c оценками критиков: 	 0.401
# Коррелляция c оценками пользователей: 	 0.065
#
# 3DS
# Коррелляция c оценками критиков: 	 0.349
# Коррелляция c оценками пользователей: 	 0.222
#
# X360
# Коррелляция c оценками критиков: 	 0.34
# Коррелляция c оценками пользователей: 	 0.066
#
# PC
# Коррелляция c оценками критиков: 	 0.336
# Коррелляция c оценками пользователей: 	 -0.011

# %% [markdown]
# ## Шаг 3.7 Вывод
# В общем коррелляция между оценками критиков и продаж есть, но слабая. С критикой пользователей коррелляции нет, кроме 3DS, у которой есть слабая коррелляция.

# %% [markdown]
# <hr>
#
# ## Шаг 3.8 Анализ жанров

# %%
func_columns = ['sum', 'count', 'mean', 'median']
genre_data = data_actual.pivot_table(index='genre', values='sum_sales', aggfunc=func_columns)
genre_data.columns = func_columns
cm = sns.light_palette("green", as_cmap=True)
#Сортировка по сумме продаж
s = genre_data.sort_values('sum').style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_9922d360_4124_11ea_a6a7_02420a007493row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row1_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row1_col1 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row1_col2 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row1_col3 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row2_col0 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row2_col1 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row2_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row3_col0 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row3_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row3_col2 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row3_col3 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row4_col0 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row4_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row4_col2 {
#             background-color:  #76c176;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row4_col3 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row5_col0 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row5_col1 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row5_col2 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row5_col3 {
#             background-color:  #76c176;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row6_col0 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row6_col1 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row6_col2 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row6_col3 {
#             background-color:  #a3daa3;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row7_col0 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row7_col1 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row7_col2 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row7_col3 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row8_col0 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row8_col1 {
#             background-color:  #9ed79e;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row8_col2 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row8_col3 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row9_col0 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row9_col1 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row9_col2 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row9_col3 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row10_col0 {
#             background-color:  #269526;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row10_col1 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row10_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row10_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row11_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row11_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row11_col2 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_9922d360_4124_11ea_a6a7_02420a007493row11_col3 {
#             background-color:  #97d497;
#             color:  #000000;
#         }</style><table id="T_9922d360_4124_11ea_a6a7_02420a007493" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sum</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >mean</th>        <th class="col_heading level0 col3" >median</th>    </tr>    <tr>        <th class="index_name level0" >genre</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9922d360_4124_11ea_a6a7_02420a007493level0_row0" class="row_heading level0 row0" >Puzzle</th>
#                         <td id="T_9922d360_4124_11ea_a6a7_02420a007493row0_col0" class="data row0 col0" >6.28</td>
#                         <td id="T_9922d360_4124_11ea_a6a7_02420a007493row0_col1" class="data row0 col1" >37</td>
#                         <td id="T_9922d360_4124_11ea_a6a7_02420a007493row0_col2" class="data row0 col2" >0.16973</td>
#                         <td id="T_9922d360_4124_11ea_a6a7_02420a007493row0_col3" class="data row0 col3" >0.06</td>
#             </tr>
#             <tr>
#                         <th id="T_9922d360_4124_11ea_a6a7_02420a007493level0_row1" class="row_heading level0 row1" >Strategy</th>
#                         <td id="T_9922d360_4124_11ea_a6a7_02420a007493row1_col0" class="data row1 col0" >25.05</td>
#                         <td id="T_9922d360_4124_11ea_a6a7_02420a007493row1_col1" class="data row1 col1" >108</td>
#                         <t

# %%
#Сортировка по медиане
s = genre_data.sort_values('median').style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col0 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col1 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row2_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row2_col1 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row2_col2 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row2_col3 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row3_col0 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row3_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row3_col2 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row3_col3 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row4_col0 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row4_col1 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row4_col2 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row4_col3 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row5_col0 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row5_col1 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row5_col2 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row5_col3 {
#             background-color:  #a3daa3;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row6_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row6_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row6_col2 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row6_col3 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row7_col0 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row7_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row7_col2 {
#             background-color:  #76c176;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row7_col3 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row8_col0 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row8_col1 {
#             background-color:  #9ed79e;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row8_col2 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row8_col3 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row9_col0 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row9_col1 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row9_col2 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row9_col3 {
#             background-color:  #76c176;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row10_col0 {
#             background-color:  #78c278;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row10_col1 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row10_col2 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row10_col3 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row11_col0 {
#             background-color:  #269526;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row11_col1 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row11_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_992ba0a8_4124_11ea_a6a7_02420a007493row11_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_992ba0a8_4124_11ea_a6a7_02420a007493" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sum</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >mean</th>        <th class="col_heading level0 col3" >median</th>    </tr>    <tr>        <th class="index_name level0" >genre</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_992ba0a8_4124_11ea_a6a7_02420a007493level0_row0" class="row_heading level0 row0" >Adventure</th>
#                         <td id="T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col0" class="data row0 col0" >39.55</td>
#                         <td id="T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col1" class="data row0 col1" >208</td>
#                         <td id="T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col2" class="data row0 col2" >0.190144</td>
#                         <td id="T_992ba0a8_4124_11ea_a6a7_02420a007493row0_col3" class="data row0 col3" >0.06</td>
#             </tr>
#             <tr>
#                         <th id="T_992ba0a8_4124_11ea_a6a7_02420a007493level0_row1" class="row_heading level0 row1" >Puzzle</th>
#                         <td id="T_992ba0a8_4124_11ea_a6a7_02420a007493row1_col0" class="data row1 col0" >6.28</td>
#                         <td id="T_992ba0a8_4124_11ea_a6a7_02420a007493row1_col1" class="data row1 col1" >37</td>

# %% [markdown]
# ## Шаг 3.8 Вывод
# Очевидно, что чем больше выпущенных игр на платформу, тем больше продаж.<br>
# Жанры Shooter и Action сильно опережают остальные. При этом хоть Shooter на втором месте по суммарным продаже, по медианным и средним продажам он на первом.<br>
# Puzzle имеют совсем маленькие проажи. Adventure тоже слабо продавались, несмотря на то, что по количеству выпущенных игр не в самом конце.

# %% [markdown]
# <hr>
#
# # Шаг 4 Портрет пользователей по регионам

# %% [markdown]
# ## Шаг 4.1 Продажи по платформам

# %%
region_pf_data = data_actual.pivot_table(index='platform', values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc='sum')
s = region_pf_data.sort_values('eu_sales').style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_9932656e_4124_11ea_a6a7_02420a007493row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row0_col2 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row0_col3 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row1_col0 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row1_col2 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row2_col0 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row2_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row3_col0 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row3_col1 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row3_col2 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row3_col3 {
#             background-color:  #76c176;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row4_col0 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row4_col1 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row4_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row4_col3 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row5_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row5_col1 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row5_col2 {
#             background-color:  #52ad52;
#             color:  #000000;
#         }    #T_9932656e_4124_11ea_a6a7_02420a007493row5_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_9932656e_4124_11ea_a6a7_02420a007493" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eu_sales</th>        <th class="col_heading level0 col1" >jp_sales</th>        <th class="col_heading level0 col2" >na_sales</th>        <th class="col_heading level0 col3" >other_sales</th>    </tr>    <tr>        <th class="index_name level0" >platform</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9932656e_4124_11ea_a6a7_02420a007493level0_row0" class="row_heading level0 row0" >XOne</th>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row0_col0" class="data row0 col0" >51.59</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row0_col1" class="data row0 col1" >0.34</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row0_col2" class="data row0 col2" >93.12</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row0_col3" class="data row0 col3" >14.27</td>
#             </tr>
#             <tr>
#                         <th id="T_9932656e_4124_11ea_a6a7_02420a007493level0_row1" class="row_heading level0 row1" >3DS</th>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row1_col0" class="data row1 col0" >61.27</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row1_col1" class="data row1 col1" >100.62</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row1_col2" class="data row1 col2" >82.65</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row1_col3" class="data row1 col3" >13.27</td>
#             </tr>
#             <tr>
#                         <th id="T_9932656e_4124_11ea_a6a7_02420a007493level0_row2" class="row_heading level0 row2" >PC</th>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row2_col0" class="data row2 col0" >68.82</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row2_col2" class="data row2 col2" >39.07</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row2_col3" class="data row2 col3" >14.07</td>
#             </tr>
#             <tr>
#                         <th id="T_9932656e_4124_11ea_a6a7_02420a007493level0_row3" class="row_heading level0 row3" >PS4</th>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row3_col0" class="data row3 col0" >141.09</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row3_col1" class="data row3 col1" >15.96</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row3_col2" class="data row3 col2" >108.74</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row3_col3" class="data row3 col3" >48.35</td>
#             </tr>
#             <tr>
#                         <th id="T_9932656e_4124_11ea_a6a7_02420a007493level0_row4" class="row_heading level0 row4" >X360</th>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row4_col0" class="data row4 col0" >163.41</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row4_col1" class="data row4 col1" >5.46</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row4_col2" class="data row4 col2" >334.18</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row4_col3" class="data row4 col3" >47.36</td>
#             </tr>
#             <tr>
#                         <th id="T_9932656e_4124_11ea_a6a7_02420a007493level0_row5" class="row_heading level0 row5" >PS3</th>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row5_col0" class="data row5 col0" >213.6</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row5_col1" class="data row5 col1" >59.26</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row5_col2" class="data row5 col2" >229.25</td>
#                         <td id="T_9932656e_4124_11ea_a6a7_02420a007493row5_col3" class="data row5 col3" >85.63</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <hr>
#
# ## Шаг 4.2 Продажи по жанрам

# %%
region_genre_data = data_actual.pivot_table(index='genre', values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc='sum')
s = region_genre_data.sort_values('eu_sales').style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_993dbebe_4124_11ea_a6a7_02420a007493row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row1_col0 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row1_col2 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row1_col3 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row2_col0 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row2_col1 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row2_col2 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row2_col3 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row3_col0 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row3_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row3_col2 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row3_col3 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row4_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row4_col1 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row4_col2 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row4_col3 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row5_col0 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row5_col1 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row5_col2 {
#             background-color:  #d6f7d6;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row5_col3 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row6_col0 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row6_col1 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row6_col2 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row6_col3 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row7_col0 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row7_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row7_col2 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row7_col3 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row8_col0 {
#             background-color:  #9cd69c;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row8_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row8_col2 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row8_col3 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row9_col0 {
#             background-color:  #75c175;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row9_col1 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row9_col2 {
#             background-color:  #6bbb6b;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row9_col3 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row10_col0 {
#             background-color:  #269526;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row10_col1 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row10_col2 {
#             background-color:  #078407;
#             color:  #f1f1f1;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row10_col3 {
#             background-color:  #259425;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row11_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row11_col1 {
#             background-color:  #1d901d;
#             color:  #000000;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row11_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_993dbebe_4124_11ea_a6a7_02420a007493row11_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_993dbebe_4124_11ea_a6a7_02420a007493" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eu_sales</th>        <th class="col_heading level0 col1" >jp_sales</th>        <th class="col_heading level0 col2" >na_sales</th>        <th class="col_heading level0 col3" >other_sales</th>    </tr>    <tr>        <th class="index_name level0" >genre</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_993dbebe_4124_11ea_a6a7_02420a007493level0_row0" class="row_heading level0 row0" >Puzzle</th>
#                         <td id="T_993dbebe_4124_11ea_a6a7_02420a007493row0_col0" class="data row0 col0" >2.66</td>
#                         <td id="T_993dbebe_4124_11ea_a6a7_02420a007493row0_col1" class="data row0 col1" >1.84</td>
#                         <td id="T_993dbebe_4124_11ea_a6a7_02420a007493row0_col2" class="data row0 col2" >1.36</td>
#                         <td id="T_993dbebe_4124_11ea_a6a7_02420a007493row0_col3" class="data row0 col3" >0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_993dbebe_4124_11ea_a6a7_02420a007493level0_row1" class="row_heading level0 row1" >Strategy</th>
#                         <td id="T_993dbebe_4124_11ea_a6a7_02420a007493row1_col0" class="data row1 col0" >10.97</td>
#                         <td id="T_993dbebe_4124_11ea_a6a7_02420a007493row1_col1" class="data row1 col1" >2.02</td>

# %% [markdown]
# <hr>
#
# ## Шаг 4.3 Продажи по возрастному рейтингу
# Для справки: <br>
# «EC» («Early childhood») — «Для детей младшего возраста» <br>
# «E» («Everyone») — «Для всех» <br>
# «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше» <br>
# «T» («Teen») — «Подросткам» <br>
# «M» («Mature») — «Для взрослых» <br>
# «AO» («Adults Only 18+») — «Только для взрослых» <br>
# «RP» («Rating Pending») — «Рейтинг ожидается» <br>

# %%
region_rating_data = data_actual.pivot_table(index='rating', values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], aggfunc='sum')
s = region_rating_data.sort_values('eu_sales').style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_9944306e_4124_11ea_a6a7_02420a007493row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row2_col0 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row2_col1 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row2_col2 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row2_col3 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row3_col0 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row3_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row3_col2 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row3_col3 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row4_col0 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row4_col1 {
#             background-color:  #038103;
#             color:  #f1f1f1;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row4_col2 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row4_col3 {
#             background-color:  #79c379;
#             color:  #000000;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row5_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row5_col1 {
#             background-color:  #0a850a;
#             color:  #f1f1f1;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row5_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_9944306e_4124_11ea_a6a7_02420a007493row5_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_9944306e_4124_11ea_a6a7_02420a007493" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eu_sales</th>        <th class="col_heading level0 col1" >jp_sales</th>        <th class="col_heading level0 col2" >na_sales</th>        <th class="col_heading level0 col3" >other_sales</th>    </tr>    <tr>        <th class="index_name level0" >rating</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9944306e_4124_11ea_a6a7_02420a007493level0_row0" class="row_heading level0 row0" >EC</th>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row0_col2" class="data row0 col2" >0.09</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_9944306e_4124_11ea_a6a7_02420a007493level0_row1" class="row_heading level0 row1" >RP</th>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row1_col0" class="data row1 col0" >0.03</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row1_col3" class="data row1 col3" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_9944306e_4124_11ea_a6a7_02420a007493level0_row2" class="row_heading level0 row2" >E10+</th>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row2_col0" class="data row2 col0" >56.89</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row2_col1" class="data row2 col1" >6.02</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row2_col2" class="data row2 col2" >86.9</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row2_col3" class="data row2 col3" >18.87</td>
#             </tr>
#             <tr>
#                         <th id="T_9944306e_4124_11ea_a6a7_02420a007493level0_row3" class="row_heading level0 row3" >T</th>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row3_col0" class="data row3 col0" >100.03</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row3_col1" class="data row3 col1" >28.79</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row3_col2" class="data row3 col2" >134.24</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row3_col3" class="data row3 col3" >33.38</td>
#             </tr>
#             <tr>
#                         <th id="T_9944306e_4124_11ea_a6a7_02420a007493level0_row4" class="row_heading level0 row4" >E</th>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row4_col0" class="data row4 col0" >147.47</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row4_col1" class="data row4 col1" >28.37</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row4_col2" class="data row4 col2" >179.62</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row4_col3" class="data row4 col3" >44.64</td>
#             </tr>
#             <tr>
#                         <th id="T_9944306e_4124_11ea_a6a7_02420a007493level0_row5" class="row_heading level0 row5" >M</th>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row5_col0" class="data row5 col0" >286.03</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row5_col1" class="data row5 col1" >27.51</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row5_col2" class="data row5 col2" >373.44</td>
#                         <td id="T_9944306e_4124_11ea_a6a7_02420a007493row5_col3" class="data row5 col3" >94.03</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Шаг 4 Вывод
#
# **Европа**: <br>
# Платформы: PS3, PS4, X360<br>
# Жанры: Sports, Shooter, Action<br>
# Рейтинги: M, E, T <br>
# <br>
# **Япония**: <br>
# Платформы: PS3, PS4, 3DS<br>
# Жанры: Role-Playing, Shooter, Action<br>
# Рейтинги: M, E, T <br>
# <br>
# **Северная Америка**: <br>
# Платформы: PS3, PS4, X360<br>
# Жанры: Sports, Shooter, Action<br>
# Рейтинги: M, E, T <br>
# <br>
# **Остальные регионы**: <br>
# Платформы: PS3, PS4, X360<br>
# Жанры: Sports, Shooter, Action<br>
# Рейтинги: M, E, T <br>
# <br>
# В общем, только япония сильно отличается от других по жанру и платформам. Видимо Япония предпочитает PS3 и PS4 из-за того, что производитель платформы их компания Sony, а Северная Америка - X360,  потому что производитель Microsoft. Другие регионы склоняются к PS3, но не с таким сильным отрывом от X360.

# %% [markdown]
# <hr>
#
# # Шаг 5 Проверка гипотез

# %%
# Функция вывода информации по таблицам
def print_var_mean(*series):
    for s in series:
        print(s._title, '\n', 'Дисперсия:', np.var(s), '\t Среднее:', np.mean(s), '\n')

# %% [markdown]
# ## Шаг 5.1 Пользовательские рейтинги платформ Xbox One и PC
# H<sub>0</sub> - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %%
user_score_pc = data_actual[data_actual['platform'] == 'PC']['user_score'].dropna()
# Зададим название таблица для вывода в функции
user_score_pc._title = 'PC'
user_score_xone = data_actual[data_actual['platform'] == 'XOne']['user_score'].dropna()
# Зададим название таблица для вывода в функции
user_score_xone._title = 'XOne'
print_var_mean(user_score_pc, user_score_xone)
# Out:
# PC
#  Дисперсия: 2.4438940204180843 	 Среднее: 6.5181818181818185
#
# XOne
#  Дисперсия: 1.8965188383045526 	 Среднее: 6.521428571428572

# %%
alpha = .05 # выбираем стандартное значение
results = st.ttest_ind(
    user_score_pc, 
    user_score_xone,
    equal_var=False # Так как дисперсии отличаются
)
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.9801634129117883
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ## Шаг 5.1 Вывод
# Нулевая гипотеза не отвергнута, значит средние пользовательские рейтинги платформ XOne и PC одинаковые

# %% [markdown]
# <hr>
#
# ## Шаг 5.2 Средние пользовательские рейтинги жанров Action и Sports
# H<sub>0</sub> - Средние пользовательские рейтинги жанров Action и Sports одинаковые

# %%
user_score_action = data_actual[data_actual['genre'] == 'Action']['user_score'].dropna()
# Зададим название таблица для вывода в функции
user_score_action._title = 'Action'
user_score_sports = data_actual[data_actual['genre'] == 'Sports']['user_score'].dropna()
# Зададим название таблица для вывода в функции
user_score_sports._title = 'Sports'
print_var_mean(user_score_action, user_score_sports)
# Out:
# Action
#  Дисперсия: 1.8086115220249837 	 Среднее: 6.746794871794871
#
# Sports
#  Дисперсия: 2.8045173415836575 	 Среднее: 5.768441064638783

# %%
alpha = .05 # выбираем стандартное значение
results = st.ttest_ind(
    user_score_action, 
    user_score_sports,
    equal_var=False # Так как дисперсии отличаются
)
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 8.079827060791015e-16
# Отвергаем нулевую гипотезу

# %% [markdown]
# ## Шаг 5.2 Вывод
# Нулевая гипотеза отвергнута, значит средние пользовательские рейтинги жанров Action и Sports отличаются

# %% [markdown]
# <hr>
#
# # Шаг 6 Выводы

# %% [markdown]
# В Японии стледует делать упор на игры жанра Role-play и Action на платформы PS4, PS3, 3DS. <br>
# В Северной Америке на жанры Action, Shooter и Sports на платформы XOne, X360 <br>
# В остальных регионах жанры Action, Shooter и Sports, но платформы можно выбрать X360, PS3, т.е. можно сказать, что пользователи почти в равной степени предпочитают обе платформы, в то время как Япония и Сев.Америка больше поддерживают своих отечественных производителей.<br>
# Также стоит учесть, что на консоли предпоследнего поколения (PS3, X360) уже почти ничего не покупают, поэтому ставку стоит делать на PS4 и XOne.<br>
# Небольшую рекламную кампанию можно сделать на PC во всех регионах, т.к. это платформа хоть и не вырывается, но стабильно держится.
# <hr>
#
# **Рекомендации к файлу датасета**: <br>
# Имеются много пропусков в рейтингах, оценках критиков и пользователей, хотя в интернете на различных сайтах (wiki, Metacritic) информация есть, поэтому стоит обновить информацию. (возможно на момент сбора инфы в 2016 году этих данных действительно не было)

# %%
import pandas as pd

d = {'value': [1, 2, 5, 3, 2, 5], 'wd': [1, 3, 5, 1, 3, 5]}
data = pd.DataFrame(d)
data.groupby('wd')['value'].mean()
# Out:
# wd
# 1    2
# 3    2
# 5    5
# Name: value, dtype: int64
